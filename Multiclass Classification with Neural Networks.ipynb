# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib widget
from sklearn.datasets import make_blobs
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
np.set_printoptions(precision=2)
import sys 
sys.path.insert(1, 'D:/Umama/MachineLearning/Course2')
from lab_utils_multiclass_TF import *
import logging
logging.getLogger("tensorflow").setLevel(logging.ERROR)
tf.autograph.set_verbosity(0)

# %%
# make 4-class dataset for classification
classes = 4
m = 100
centers = [[-5, 2], [-2, -2], [1, 2], [5, -2]]
std = 1.0
X_train, y_train = make_blobs(n_samples=m, centers=centers, cluster_std=std,random_state=30)

# %%
plt_mc(X_train,y_train,classes, centers, std=std)
# Out:
# D:\Umama/MachineLearning/Course2\lab_utils_multiclass_TF.py:63: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(X[idx, 0], X[idx, 1],  marker=m,
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %%
# show classes in data set
print(f"unique classes {np.unique(y_train)}")
# show how classes are represented
print(f"class representation {y_train[:10]}")
# show shapes of our dataset
print(f"shape of X_train: {X_train.shape}, shape of y_train: {y_train.shape}")
# Out:
# unique classes [0 1 2 3]
# class representation [3 3 3 0 3 3 3 3 2 0]
# shape of X_train: (100, 2), shape of y_train: (100,)

# %%
tf.random.set_seed(1234)  # applied to achieve consistent results
model = Sequential(
    [
        Dense(2, activation = 'relu',   name = "L1"),
        Dense(4, activation = 'linear', name = "L2")
    ]
)

# %%
model.compile(
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer=tf.keras.optimizers.Adam(0.01),
)

model.fit(
    X_train,y_train,
    epochs=200
)
# Out:
# Epoch 1/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0766
# Epoch 2/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 1.0506
# Epoch 3/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 1.0323
# Epoch 4/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0174
# Epoch 5/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 1.0045
# Epoch 6/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.9930
# Epoch 7/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.9823
# Epoch 8/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step - loss: 0.9721
# Epoch 9/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.9625
# Epoch 10/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.9533
# Epoch 11/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.9444
# Epoch 12/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.9357
# Epoch 13/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.9271
# Epoch 14/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.9186
# Epoch 15/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9101
# Epoch 16/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.9015
# Epoch 17/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.8924
# Epoch 18/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.8823
# Epoch 19/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.8717
# Epoch 20/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 785us/step - loss: 0.8606
# Epoch 21/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.8486
# Epoch 22/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.8363
# Epoch 23/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.8228
# Epoch 24/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.8086
# Epoch 25/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.7940
# Epoch 26/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.7783
# Epoch 27/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7619
# Epoch 28/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.7450
# Epoch 29/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.7279
# Epoch 30/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.7107
# Epoch 31/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6925
# Epoch 32/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6732
# Epoch 33/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step - loss: 0.6542
# Epoch 34/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.6352
# Epoch 35/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6160
# Epoch 36/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.5974
# Epoch 37/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.5799
# Epoch 38/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.5636
# Epoch 39/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.5484
# Epoch 40/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5344
# Epoch 41/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.5211
# Epoch 42/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step - loss: 0.5083
# Epoch 43/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.4957
# Epoch 44/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step - loss: 0.4827
# Epoch 45/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4691
# Epoch 46/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4533
# Epoch 47/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.4338
# Epoch 48/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4118
# Epoch 49/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.3849
# Epoch 50/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.3608
# Epoch 51/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step - loss: 0.3380
# Epoch 52/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.3149
# Epoch 53/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.2965
# Epoch 54/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.2805
# Epoch 55/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.2652
# Epoch 56/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.2505
# Epoch 57/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.2362
# Epoch 58/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 665us/step - loss: 0.2231
# Epoch 59/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2112
# Epoch 60/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.2004
# Epoch 61/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.1906
# Epoch 62/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1816
# Epoch 63/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.1733
# Epoch 64/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.1656
# Epoch 65/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.1585
# Epoch 66/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.1518
# Epoch 67/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1455
# Epoch 68/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.1397
# Epoch 69/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.1341
# Epoch 70/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1290
# Epoch 71/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step - loss: 0.1242
# Epoch 72/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step - loss: 0.1196
# Epoch 73/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.1153
# Epoch 74/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.1113
# Epoch 75/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.1075
# Epoch 76/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step - loss: 0.1040
# Epoch 77/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.1006
# Epoch 78/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0974
# Epoch 79/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0943
# Epoch 80/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0915
# Epoch 81/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0887
# Epoch 82/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0861
# Epoch 83/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0837
# Epoch 84/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0813
# Epoch 85/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0791
# Epoch 86/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.0769
# Epoch 87/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step - loss: 0.0749
# Epoch 88/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0729
# Epoch 89/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0710
# Epoch 90/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.0693
# Epoch 91/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0675
# Epoch 92/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0659
# Epoch 93/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0643
# Epoch 94/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step - loss: 0.0628
# Epoch 95/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0614
# Epoch 96/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0600
# Epoch 97/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0586
# Epoch 98/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0573
# Epoch 99/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0561
# Epoch 100/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.0549
# Epoch 101/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.0537
# Epoch 102/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step - loss: 0.0526
# Epoch 103/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0516
# Epoch 104/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.0505
# Epoch 105/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0495
# Epoch 106/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0486
# Epoch 107/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0476
# Epoch 108/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0467
# Epoch 109/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step - loss: 0.0458
# Epoch 110/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0450
# Epoch 111/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0442
# Epoch 112/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0434
# Epoch 113/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0426
# Epoch 114/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0419
# Epoch 115/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.0411
# Epoch 116/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0404
# Epoch 117/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0397
# Epoch 118/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0391
# Epoch 119/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.0384
# Epoch 120/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0378
# Epoch 121/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.0372
# Epoch 122/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.0366
# Epoch 123/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step - loss: 0.0360
# Epoch 124/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.0355
# Epoch 125/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0349
# Epoch 126/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.0344
# Epoch 127/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0339
# Epoch 128/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0333
# Epoch 129/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0329
# Epoch 130/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0324
# Epoch 131/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0319
# Epoch 132/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0314
# Epoch 133/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0310
# Epoch 134/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0306
# Epoch 135/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0301
# Epoch 136/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0297
# Epoch 137/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0293
# Epoch 138/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0289
# Epoch 139/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0285
# Epoch 140/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0281
# Epoch 141/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0278
# Epoch 142/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0274
# Epoch 143/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0270
# Epoch 144/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0267
# Epoch 145/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0263
# Epoch 146/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0260
# Epoch 147/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0257
# Epoch 148/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0254
# Epoch 149/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.0250
# Epoch 150/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0247
# Epoch 151/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0244
# Epoch 152/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0241
# Epoch 153/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0239
# Epoch 154/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0236
# Epoch 155/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.0233
# Epoch 156/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0230
# Epoch 157/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0228
# Epoch 158/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0225
# Epoch 159/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.0222
# Epoch 160/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0220
# Epoch 161/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.0217
# Epoch 162/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.0215
# Epoch 163/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0212
# Epoch 164/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0210
# Epoch 165/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0208
# Epoch 166/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0205
# Epoch 167/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0203
# Epoch 168/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0201
# Epoch 169/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0199
# Epoch 170/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0197
# Epoch 171/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0195
# Epoch 172/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0193
# Epoch 173/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 657us/step - loss: 0.0191
# Epoch 174/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0189
# Epoch 175/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0187
# Epoch 176/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0185
# Epoch 177/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0183
# Epoch 178/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0181
# Epoch 179/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0179
# Epoch 180/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0177
# Epoch 181/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0176
# Epoch 182/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0174
# Epoch 183/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0172
# Epoch 184/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.0171
# Epoch 185/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0169
# Epoch 186/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0167
# Epoch 187/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0166
# Epoch 188/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0164
# Epoch 189/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0163
# Epoch 190/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0161
# Epoch 191/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0159
# Epoch 192/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0158
# Epoch 193/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0156
# Epoch 194/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0155
# Epoch 195/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0154
# Epoch 196/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0152
# Epoch 197/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0151
# Epoch 198/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step - loss: 0.0149
# Epoch 199/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0148
# Epoch 200/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0147

# %%
plt_cat_mc(X_train, y_train, model, classes)
# Out:
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 377us/step
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %%
# gather the trained parameters from the first layer
l1 = model.get_layer("L1")
W1,b1 = l1.get_weights()

# %%
# plot the function of the first layer
plt_layer_relu(X_train, y_train.reshape(-1,), W1, b1, classes)
# Out:
# D:\Umama/MachineLearning/Course2\lab_utils_multiclass_TF.py:63: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(X[idx, 0], X[idx, 1],  marker=m,
# D:\Umama/MachineLearning/Course2\lab_utils_multiclass_TF.py:63: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(X[idx, 0], X[idx, 1],  marker=m,
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %%
# gather the trained parameters from the output layer
l2 = model.get_layer("L2")
W2, b2 = l2.get_weights()
# create the 'new features', the training examples after L1 transformation
Xl2 = np.maximum(0, np.dot(X_train,W1) + b1)

plt_output_layer_linear(Xl2, y_train.reshape(-1,), W2, b2, classes,
                        x0_rng = (-0.25,np.amax(Xl2[:,0])), x1_rng = (-0.25,np.amax(Xl2[:,1])))
# Out:
# D:\Umama/MachineLearning/Course2\lab_utils_multiclass_TF.py:63: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(X[idx, 0], X[idx, 1],  marker=m,
# D:\Umama/MachineLearning/Course2\lab_utils_multiclass_TF.py:63: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(X[idx, 0], X[idx, 1],  marker=m,
# D:\Umama/MachineLearning/Course2\lab_utils_multiclass_TF.py:63: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(X[idx, 0], X[idx, 1],  marker=m,
# D:\Umama/MachineLearning/Course2\lab_utils_multiclass_TF.py:63: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(X[idx, 0], X[idx, 1],  marker=m,
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …
